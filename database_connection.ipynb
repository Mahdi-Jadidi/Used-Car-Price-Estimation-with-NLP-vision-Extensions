# %%
import sqlite3
import os

DB_PATH = os.path.join(os.getcwd(), 'database', 'final_car_database.db')

def get_connection():
    print(DB_PATH)
    return sqlite3.connect(DB_PATH)

# %%
print(get_connection())
# Out:
# /home/sami/Documents/DataScience/Final Project/database/final_car_database.db
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(get_connection())
#
# Cell In[6], line 8, in get_connection()
#       6 def get_connection():
#       7     print(DB_PATH)
# ----> 8     return sqlite3.connect(DB_PATH)
#
# OperationalError: unable to open database file
